# %% [markdown]
# #  Seaborn: statistical data visualization

# %%
import pandas as pd
# Import the air quality dataset 

CO2Data = pd.read_csv("../data/Terminos_lagoon_TA_DIC_2023_RawData.csv")

print(CO2Data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   sample                   106 non-null    object
#  1   date                     106 non-null    object
#  2   estuary                  106 non-null    object
#  3   area                     106 non-null    object
#  4   station                  106 non-null    object
#  5   layer_depth              106 non-null    object
#  6   season                   106 non-null    object
#  7   chlorophy_microg_l       106 non-null    float64
#  8   cond_microsiemens_cm     106 non-null    float64
#  9   depth_m                  106 non-null    float64
#  10  do_percent_sat           106 non-null    float64
#  11  do_mg_l                  106 non-null    float64
#  12  sal_psu                  106 non-null    float64
#  13  sp_cond_microsiemens_cm  106 non-null    float64
#  14  turbidity_fnu            106 non-null    float64
#  15  temp_c                   106 non-null    float64
#  16  latitude                 106 non-null    float64
#  17  longitude                106 non-null    float64
#  18  dic_micromol_kg          106 non-null    int64
#  19  ta_micromol_kg           106 non-null    int64
#  20  dummy_data               99 non-null     float64
# dtypes: float64(12), int64(2), object(7)
# memory usage: 17.5+ KB
# None

# %% [markdown]
# - Load libs and set figure

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

#create your own color array (viridis)
my_colors = ["#5ec962", "#3b528b"]

# add color array to set_palette
sns.set(font_scale=2, style="ticks", palette= my_colors)

# %% [markdown]
# - plot boxplot with Catplot in Seaborn

# %%
ax = sns.catplot(data=CO2Data,
                 x="area", y="ta_micromol_kg",
                hue="season", col="estuary",
                kind="box", 
                height=7, aspect=1)

  
ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()

# %% [markdown]
# - plot a violin with Catplot in Seaborn

# %%
ax = sns.catplot(data=CO2Data, 
                x="area", y="ta_micromol_kg",
                hue="season", col="estuary", 
                kind="violin", 
                height=7, aspect=1)

  
ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()

# %% [markdown]
# - Plotting a three-way ANOVA

# %%
# Draw a pointplot to show pulse as a function of three categorical factors
ax = sns.catplot(
    data=CO2Data, x="season", 
    y="ta_micromol_kg", hue="estuary", col="area",
    capsize=.2, palette="YlGnBu_d", errorbar="se",
    kind="point", height=6, aspect=.75,
)
ax.despine(left=True)

ax.set(xlabel='', ylabel=' TA ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()

# %% [markdown]
# - Scatterplots DIC vs Salinity by Estuary

# %%
ax = sns.lmplot(x="sal_psu", y="ta_micromol_kg",
                hue="season",col="estuary",
                data=CO2Data, 
                height=7, aspect=1)

ax.set(xlabel='Salinity (PSU)', ylabel=' DIC ($\mu mol \; kg^{-1}$)')

ax.set_titles(col_template="{col_name}", row_template="{row_name}")

plt.setp(ax._legend.get_title(), fontsize=20)

sns.despine(top=False,right=False)

plt.show()

# %% [markdown]
# ## Exercise
# - How can you modify the units of the figures?
# - Check the examples at https://seaborn.pydata.org/ and create your own figures. If possible, use your own data.

# %%
import pandas as pd
# Import  dataset 
NaborData = pd.read_csv("Nabor.csv")

print(NaborData.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 71 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CLAVE SITIO          32 non-null     object
#  1   CLAVE MONITOREO      32 non-null     object
#  2   NOMBRE DEL SITIO     32 non-null     object
#  3   MES                  32 non-null     object
#  4   AÑO                  32 non-null     int64
#  5   FECHA                32 non-null     object
#  6   CLOROF_A             28 non-null     float64
#  7   COLI_FEC             32 non-null     object
#  8   COLI_TOT             0 non-null      float64
#  9   E_COLI               32 non-null     float64
#  10  COT                  32 non-null     float64
#  11  COT_SOL              32 non-null     float64
#  12  DBO_SOL              32 non-null     object
#  13  DBO_TOT              32 non-null     int64
#  14  DQO_SOL              32 non-null     float64
#  15  DQO_TOT              32 non-null     int64
#  16  N_NH3                32 non-null     float64
#  17  N_NO2                32 non-null     object
#  18  N_NO3                32 non-null     object
#  19  N_ORG                32 non-null     float64
#  20  N_TOT                32 non-null     float64
#  21  N_TOTK               32 non-null     float64
#  22  TOX_D_48_SUP_UT      29 non-null     object
#  23  TOX_D_48_FON_UT      9 non-null      object
#  24  TOX_FIS_SUP_15_UT    32 non-null     object
#  25  TOX_FIS_SUP_30_UT    12 non-null     object
#  26  TOX_FIS_SUP_5_UT     30 non-null     object
#  27  TOX_FIS_FON_15_UT    10 non-null     object
#  28  TOX_FIS_FON_30_UT    2 non-null      object
#  29  TOX_FIS_FON_5_UT     11 non-null     object
#  30  P_TOT                32 non-null     float64
#  31  PO4_TOT              0 non-null      float64
#  32  ORTO_PO4             30 non-null     float64
#  33  COLOR_VER            31 non-null     float64
#  34  TRANSPARENCIA        30 non-null     float64
#  35  ABS_UV               30 non-null     float64
#  36  SDT                  32 non-null     float64
#  37  CONDUC_CAMPO_SUP     32 non-null     float64
#  38  CONDUC_CAMPO_MED     5 non-null      float64
#  39  CONDUC_CAMPO_FON     10 non-null     float64
#  40  pH_CAMPO_SUP         28 non-null     float64
#  41  pH_CAMPO_MED         3 non-null      float64
#  42  pH_CAMPO_FON         6 non-null      float64
#  43  OD_%_SUP             13 non-null     object
#  44  OD_mg/L_SUP          17 non-null     float64
#  45  OD_%_MED             1 non-null      float64
#  46  OD_mg/L_MED          1 non-null      float64
#  47  OD_%_FON             3 non-null      float64
#  48  OD_mg/L_FON          3 non-null      float64
#  49  SST                  32 non-null     object
#  50  TURBIEDAD            32 non-null     object
#  51  AS_TOT               32 non-null     object
#  52  CD_TOT               32 non-null     object
#  53  CR_TOT               32 non-null     object
#  54  HG_TOT               29 non-null     object
#  55  NI_TOT               32 non-null     object
#  56  PB_TOT               32 non-null     object
#  57  POT_REDOX_CAMPO_SUP  29 non-null     float64
#  58  POT_REDOX_CAMPO_MED  5 non-null      float64
#  59  POT_REDOX_CAMPO_FON  10 non-null     float64
#  60  DUR_TOT              32 non-null     float64
#  61  TEMP_AMB             32 non-null     float64
#  62  TEMP_AGUA            0 non-null      float64
#  63  TEMP_AGUA_SUP        30 non-null     float64
#  64  TEMP_AGUA_MED        5 non-null      float64
#  65  TEMP_AGUA_FON        10 non-null     float64
#  66  TEMP_AGUA_0.5        32 non-null     float64
#  67  TEMP_AGUA_1          18 non-null     float64
#  68  TEMP_AGUA_2          6 non-null      float64
#  69  PROFUNDIDAD          26 non-null     float64
#  70  CAUDAL               0 non-null      float64
# dtypes: float64(42), int64(3), object(26)
# memory usage: 17.9+ KB
# None

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
sns.boxplot(
    data=NaborData,
    x="AÑO", 
    y="P_TOT",
    palette="Set2",   # paleta de colores
    showfliers=False  # ocultar outliers para que no tape los puntos     # dispersa los puntos para que no se encimen
)

plt.xlabel("Año", fontsize=14)
plt.ylabel("PT (mg/L)", fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.title("Distribución anual de P en lago Nabor Carrillo", fontsize=16)
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_1864\172663781.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
