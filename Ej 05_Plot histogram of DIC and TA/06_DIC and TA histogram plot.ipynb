# %% [markdown]
# #  Explore environmental data using Pandas

# %%
import pandas as pd

# Import the air quality dataset 
CO2Data = pd.read_csv("../data/Terminos_lagoon_TA_DIC_2023_RawData.csv")

print(CO2Data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   sample                   106 non-null    object
#  1   date                     106 non-null    object
#  2   estuary                  106 non-null    object
#  3   area                     106 non-null    object
#  4   station                  106 non-null    object
#  5   layer_depth              106 non-null    object
#  6   season                   106 non-null    object
#  7   chlorophy_microg_l       106 non-null    float64
#  8   cond_microsiemens_cm     106 non-null    float64
#  9   depth_m                  106 non-null    float64
#  10  do_percent_sat           106 non-null    float64
#  11  do_mg_l                  106 non-null    float64
#  12  sal_psu                  106 non-null    float64
#  13  sp_cond_microsiemens_cm  106 non-null    float64
# ...

# %% [markdown]
# - Plot a simple histogram

# %%
import matplotlib.pyplot as plt

# Select data
sal_data = CO2Data["sal_psu"]

plt.hist(sal_data, bins=10)
plt.xlabel("Salinity (PSU)")
plt.ylabel("Probablity")
plt.show()

# %% [markdown]
# - Normalize our inputs by the total number of counts

# %%
# Plot the histogram with density (nomalized)
# Select data 
data = CO2Data["sal_psu"]


plt.hist(data, bins=10, density=True)
plt.xlabel("Salinity (PSU)")
plt.ylabel("Probablity")
plt.show()

# %% [markdown]
# - Boxplot Demo

# %%
# Creating plot

do_data = CO2Data["do_mg_l"]
plt.boxplot(do_data)

plt.xlabel("DO (mg/L)")
plt.ylabel("Concentration")
plt.title("Boxplot of DO Concentration")

# show plot
plt.show()

# %%
# Plot boxplot for salinity data
data = CO2Data["sal_psu"]

fig2, ax2 = plt.subplots()

ax2.set_title('Notched boxes')
ax2.boxplot(data, notch=True)

plt.ylabel('Salinity ($PSU$)', fontsize = 12)
plt.show()

# %% [markdown]
# - Boxplot Demo 2

# %%
# Plot boxplot for TA data
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()

ax3.set_title('Changed Outlier Symbols')

ax3.boxplot(data, flierprops=green_diamond)


plt.ylabel('TA ($\mu mol  \; kg^{-1}$)', fontsize = 12)
plt.show()

# %% [markdown]
# ## Exercise
# -  ### Plot histogram of DIC and TA

# %%
import matplotlib.pyplot as plt

DIC_data = CO2Data["dic_micromol_kg"]

plt.figure(figsize=(10,5))
plt.hist(DIC_data, bins=20, color= 'orange', edgecolor="black")

#Modificar ejes
plt.xlabel("DIC (micromol/kg)", fontsize=16)
plt.ylabel("Probablity", fontsize=16)
plt.title("Histogram of DIC", fontsize=26)
plt.tick_params(axis='both', labelsize=14)

plt.show()

# %%
import matplotlib.pyplot as plt

TA_data = CO2Data["ta_micromol_kg"]

plt.figure(figsize=(10,5))
plt.hist(DIC_data, bins=10, color= 'skyblue', edgecolor="black")

#Modificar ejes
plt.xlabel("TA (micromol/kg)", fontsize=16)
plt.ylabel("Probablity", fontsize=16)
plt.title("Histogram of total alcalinity", fontsize=26)
plt.tick_params(axis='both', labelsize=14)

plt.show()
